# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
df=pd.read_excel(r"/Users/cc1/Downloads/Week 1 Dataset.xlsx")
import warnings
warnings.filterwarnings("ignore")
sns.set(color_codes=True)
g=sns.pairplot(df, hue="Number of siblings")

# %%
print(df)
df.corr(method="pearson")
# Out:
#   Name  Income per month          State  Age Sex  Number of siblings
# 0    A                50     Tamil Nadu   23   M                   0
# 1    B                34      Karnataka   37   F                   3
# 2    C                54     Tamil Nadu   35   F                   1
# 3    D                24  Uttar Pradesh   26   F                   4
# 4    E                19          Bihar   59   M                   5
# 5    F                21          Bihar   48   M                   6
# 6    G                40          Delhi   30   F                   2
# 7    H                20  Uttar Pradesh   72   M                  10
# 8    I                30      Telangana   22   F                   0
# 9    J                18    Chattisgarh   42   M                   7
#                     Income per month       Age  Number of siblings
# Income per month            1.000000 -0.572285           -0.773257
# Age                        -0.572285  1.000000            0.856892
# ...

# %%
sns.heatmap(df.corr(), annot=True,fmt='0.0%')

# %%
sns.pairplot(df, hue="Age")

# %%
sns.pairplot(df, hue="Income per month")

# %%
df.corr(method="pearson")
# Out:
#                     Income per month       Age  Number of siblings
# Income per month            1.000000 -0.572285           -0.773257
# Age                        -0.572285  1.000000            0.856892
# Number of siblings         -0.773257  0.856892            1.000000

# %%
df.columns
# Out:
# Index(['Name', 'Income per month', 'State', 'Age', 'Sex',
#        'Number of siblings'],
#       dtype='object')

# %%
df.head()
# Out:
#   Name  Income per month          State  Age Sex  Number of siblings
# 0    A                50     Tamil Nadu   23   M                   0
# 1    B                34      Karnataka   37   F                   3
# 2    C                54     Tamil Nadu   35   F                   1
# 3    D                24  Uttar Pradesh   26   F                   4
# 4    E                19          Bihar   59   M                   5

# %%
cbar_kws = {"shrink":.8,
           'extend':'max',
           'extendfrac':.2, 
           "drawedges":True} 
sns.heatmap(df.corr(),annot=True, fmt=".1f", cmap='inferno', linewidths = 2, square= True, linecolor ="k", cbar_kws=cbar_kws)
plt.title("Heatmap Correlation of week 1 dataset", fontsize = 25)
plt.show()
